# %% [markdown]
# # Reproducible Science
#
# Scientific publications should be fully reproducible. The trend is increasing; here's a list of some recent academic publications whose results you can verify by yourself:
#
# https://github.com/ipython/ipython/wiki/A-gallery-of-interesting-IPython-Notebooks#reproducible-academic-publications
#
# For example:
#
# http://nbviewer.ipython.org/github/jansoe/FUImaging/blob/master/examples/IOSsegmentation/regNMF.ipynb

# %% [markdown]
# # Jupyter (née IPython) Notebooks
#
# Notebooks are a way to allow reproducibility and collaborative development (when used in combination with a revision control system). Notebooks are a way to collect all your thoughts and methods for a computer experiment into one, neat, place. Here are some first impressions from a happy convert:
#
# http://www.pgbovine.net/ipython-notebook-first-impressions.htm
#
# An Introduction to the Jupyter Notebooks:
#
# http://nbviewer.ipython.org/url/www.hep.caltech.edu/~piti/share/doc/ipython/examples/notebooks/01_notebook_introduction.ipynb
#
# 10-Minute Tutorial, run through the commands in your own custom notebook or from this one here below:
#
# http://nbviewer.ipython.org/github/ipython/ipython/blob/1.x/examples/notebooks/Part%201%20-%20Running%20Code.ipynb

# %% [markdown]
# # A gallery of interesting IPython Notebooks
#
#   https://github.com/ipython/ipython/wiki/A-gallery-of-interesting-IPython-Notebooks
#
# # Features:
# - Basic And Plotting:
#   http://nbviewer.ipython.org/github/rossant/ipython-minibook/blob/master/chapter4/406-plot3d.ipynb
#
# - More on plotting: http://nbviewer.ipython.org/github/jrjohansson/scientific-python-lectures/blob/master/Lecture-4-Matplotlib.ipynb
#
# - A Rich Display System
#   http://nbviewer.ipython.org/github/ipython/ipython/blob/1.x/examples/notebooks/Part%205%20-%20Rich%20Display%20System.ipynb
#
# - Markdown
#   https://daringfireball.net/projects/markdown/basics
#
# - Interactive Plotting:
#
#   http://nbviewer.ipython.org/github/damianavila/bokeh_overview/blob/master/Bokeh%20Overview.ipynb
#   http://nbviewer.ipython.org/gist/msund/7ac1203ded66fe8134cc
#
# - Interactive computing:
#   http://nbviewer.ipython.org/github/ipython/ipython/blob/master/examples/Interactive%20Widgets/Exploring%20Graphs.ipynb
#
# # Integration with other languages
#   - C++: http://nbviewer.ipython.org/github/rossant/ipython-minibook/blob/master/chapter6/602-cpp.ipynb
#   - Matlab: http://nbviewer.ipython.org/gist/anonymous/8940322
#   - R:

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# # ggplot2 examples
# library(ggplot2)
#
# # create factors with value labels
# mtcars$gear <- factor(mtcars$gear,levels=c(3,4,5),
#   	labels=c("3gears","4gears","5gears"))
# mtcars$am <- factor(mtcars$am,levels=c(0,1),
#   	labels=c("Automatic","Manual"))
# mtcars$cyl <- factor(mtcars$cyl,levels=c(4,6,8),
#    labels=c("4cyl","6cyl","8cyl"))
#
# # Kernel density plots for mpg
# # grouped by number of gears (indicated by color)
# qplot(mpg, data=mtcars, geom="density", fill=gear, alpha=I(.5),
#    main="Distribution of Gas Milage", xlab="Miles Per Gallon",
#    ylab="Density")
# Out:
# Need help? Try the ggplot2 mailing list: http://groups.google.com/group/ggplot2.
